# %% [markdown]
# <a href="https://colab.research.google.com/github/gppooja/gppooja/blob/main/Airline_Passenger_Satisfaction__EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploratory Data Analysis in Airline Passenger Satisfaction Survey**

# %% [markdown]
# ![1920-airplane-in-the-sky-over-new-york-city-3d-rendering-airplane-in-flight-at-twilight-with-blurred-cityscape-ai-generated.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Exploratory Data Analysis (EDA) is a process of describing the data by means of statistical and visualization techniques in order to bring important aspects of that data into focus for further analysis.This involves inspecting the dataset from many angles, describing & summarizing it without making any assumptions about its contents.
#
# EDA is both a science and an art. On the one hand it requires the knowledge of statistics, visualization techniques and data analysis tools like Numpy, Pandas, Seaborn etc. On the other hand, it requires asking interesting questions to guide the investigation and interpreting numbers & figures to generate useful insights.

# %% [markdown]
# Project Outline:
#
# - Downloading a dataset from an online source
# - Data preparation and cleaning with Pandas
# - Open-ended exploratory analysis and visualization
# - Asking and answering interesting questions
# - Summarizing inferences and drawing conclusions

# %% [markdown]
# Before we begin, let's install the required libraries

# %% [markdown]
# ## Introduction
#
#
#
# The data sourced from a survey conducted by airlines on the satisfaction level of passengers/customers based on various factors.Customer satisfaction plays a major role in affecting the business of a company therefore analysing and improving the factors that are closely related to customer satisfaction is important for the growth and reputation of a company.You can find the official analysis of the data here:
#  https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction?select=test.csv
#
#  There are several options for getting a dataset
#
#
# *   Download the CSV manually and upload it
# *   Use the `opendatasets` library to download datasets from Kaggle datasets and Google Drive URLs

# %%
# !pip install numpy

# %%
# !pip install opendatasets

# %%
# !pip install numpy

# %%
import opendatasets as od
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d93a2fe27d63> in <cell line: 1>()
# ----> 1 import opendatasets as od
#
# ModuleNotFoundError: No module named 'opendatasets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
url='https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction?select=test.csv'

# %%
url
# Out:
# 'https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction?select=test.csv'

# %%
od.download(url)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction
# ...
# 100%|██████████| 2.71M/2.71M [00:00<00:00, 93.1MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data=pd.read_csv("/content/testflight.csv")
data
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
flight= pd.read_csv('/content/testflight.csv')
flight
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %% [markdown]
# The dataset consists of 25976 records and 25 columns such as Age, Gender, Travel class, Arrival and Departure delays and also features that influences customer satisfaction level such as On-board service, Cleanliness, Seat comfort, Baggage handling etc respectively.
#
#
# Each row corresponds to one passenger, and each column to a specific feature.

# %% [markdown]
# Let's view some basic information about the data frame.

# %%
flight.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         25976 non-null  int64
#  1   id                                 25976 non-null  int64
#  2   Gender                             25976 non-null  object
#  3   Customer Type                      25976 non-null  object
#  4   Age                                25976 non-null  int64
#  5   Type of Travel                     25976 non-null  object
#  6   Class                              25976 non-null  object
#  7   Flight Distance                    25976 non-null  int64
#  8   Inflight wifi service              25976 non-null  int64
#  9   Departure/Arrival time convenient  25976 non-null  int64
#  10  Ease of Online booking             25976 non-null  int64
# ...

# %%
flight.describe()
# Out:
#          Unnamed: 0             id           Age  Flight Distance  \
# count  25976.000000   25976.000000  25976.000000     25976.000000
# mean   12987.500000   65005.657992     39.620958      1193.788459
# std     7498.769632   37611.526647     15.135685       998.683999
# min        0.000000      17.000000      7.000000        31.000000
# 25%     6493.750000   32170.500000     27.000000       414.000000
# 50%    12987.500000   65319.500000     40.000000       849.000000
# 75%    19481.250000   97584.250000     51.000000      1744.000000
# max    25975.000000  129877.000000     85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count           25976.000000                       25976.000000
# mean                2.724746                           3.046812
# std                 1.335384                           1.533371
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# Before we ask questions about the survey responses, it would help to understand the respondents' demographics, i.e. Age, gender, Customer Type, Type of Travel, Class, Flight Distance, Inflight wifi service	like services etc. It's essential to explore these variables to understand and improving the factors that are closely related to customer satisfaction is important for bussiness of the company.
#
# Let's begin by importing `matplotlib.pyplot` and `seaborn`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Age
#
# The distribution represent passenger's age.We can use a histogram to visualize its distribution.

# %%
flight.Age.unique()
# Out:
# array([52, 36, 20, 44, 49, 16, 77, 43, 47, 46, 33, 60, 50, 31, 55, 25, 30,
#        62, 24, 22, 51, 56, 41, 53, 12, 39, 32, 40, 42, 28, 59, 58, 27, 67,
#        70, 66, 19, 69, 35, 54, 26, 61, 21, 37, 45, 38,  7, 34, 17, 15, 48,
#        13, 11, 29,  8, 18, 23, 65, 57, 80, 64,  9, 14, 68, 10, 79, 63, 73,
#        74, 71, 72, 76, 78, 75, 85])

# %%
flight.Age.value_counts()
# Out:
# Age
# 39    723
# 25    713
# 40    635
# 41    633
# 43    626
#      ...
# 75     15
# 74     14
# 78     11
# 79     10
# 85      8
# Name: count, Length: 75, dtype: int64

# %%
flight.Age.min()
# Out:
# 7

# %%
flight.Age.max()
# Out:
# 85

# %%
flight.Age.mean()
# Out:
# 39.62095780720665

# %%
px.histogram(flight,x='Age')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The histogram displays a rougly distribution,suggesting that the ages of airline passengers are normally distributed.the most common age group appears to be between approximately 30-40 years,as indicated by tallest bars.the age distribution is skewed slightly to the right,showing a tail with a minor presence of passengers above 70 years old.

# %%
sns.histplot(x= flight.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # Gender
#
# It shows the gender of the passengers(male and female).

# %%
flight.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
flight.Gender.value_counts()
# Out:
# Gender
# Female    13172
# Male      12804
# Name: count, dtype: int64

# %%
gender=flight['Gender'].value_counts()
gender
# Out:
# Gender
# Female    13172
# Male      12804
# Name: count, dtype: int64

# %%
plt.title('gender count')
plt.pie(gender,labels=gender.index,autopct='%1.2f%%',startangle=190);

# %% [markdown]
# the number of male passenger(49.29%) is roughly equal to the number of female passengers(50.71%),with male passenger being slightly more in number.Such a balanced distribution suggests that the airline services are being utilized by both genders equally.

# %% [markdown]
# # Customer Type
#
# This is the type of the customers who travels in flight.We can use a countplot to visualize its distribution.

# %%
customer_type=flight['Customer Type']

# %%
customer_type.unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
customer_type.value_counts()
# Out:
# Customer Type
# Loyal Customer       21177
# disloyal Customer     4799
# Name: count, dtype: int64

# %%
sns.countplot(x = customer_type, hue = 'satisfaction',data=flight)
# Out:
# <Axes: xlabel='Customer Type', ylabel='count'>

# %%
sns.countplot(x = customer_type, color='pink',data=flight)
# Out:
# <Axes: xlabel='Customer Type', ylabel='count'>

# %% [markdown]
# this a distribution suggests that the airline has a strong base of loyal customers who choose to travel with them repeatedly.the disloyal customers are less compare to loyal customer.
# understanding the proportion of loyal customer versus disloyal customers is crucial for the airline's customer relationship management and for developing strategies to maintain customer loyalty and attract new business.

# %% [markdown]
# # Class

# %%
flight.Class.unique()
# Out:
# array(['Eco', 'Business', 'Eco Plus'], dtype=object)

# %%
flight.Class.value_counts()
# Out:
# Class
# Business    12495
# Eco         11564
# Eco Plus     1917
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Class', hue = 'satisfaction', palette = "YlOrBr",data=flight)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# # Flight Distance
#
# It shows flight distance of the journey in miles.we can use boxplot to visualize its distribution.

# %%
distance=flight['Flight Distance']
distance.nunique()
# Out:
# 3281

# %%
sns.boxplot(x=distance)
# Out:
# <Axes: xlabel='Flight Distance'>

# %%
distance.max()
# Out:
# 4983

# %%
flight[distance==4983]
# Out:
#        Unnamed: 0     id  Gender   Customer Type  Age   Type of Travel  \
# 7851         7851  31874  Female  Loyal Customer   33  Business travel
# 11779       11779  31816  Female  Loyal Customer   45  Personal Travel
# 14261       14261  31872    Male  Loyal Customer   46  Business travel
# 14615       14615  31815  Female  Loyal Customer   49  Business travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 7851   Business             4983                      1
# 11779       Eco             4983                      3
# 14261  Business             4983                      1
# 14615  Business             4983                      4
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# 7851                                   1                       1
# 11779                                  1                       3
# 14261                                  1                       1
# ...

# %%
px.box(x=distance)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# A box plot is a way to represent flight distance on a number line.The sides of the box represent the first and third quartiles. A line inside the box represents the median. Lines outside the box connect to the minimum and maximum values of distance.it helps to identifies the outliers of the flight distance.It shows few people's travels long distance.

# %%
arrival=flight['Arrival Delay in Minutes']
departure=flight['Departure Delay in Minutes']
dep_arr_time=flight['Departure/Arrival time convenient']
online_booking=flight['Ease of Online booking']
customer_type=flight['Customer Type']
wifi=flight['Inflight wifi service']
food=flight['Food and drink']
seat_comfort=flight['Seat comfort']

# %%
sns.scatterplot(x=flight.Age, y =distance,hue=flight.Class)
# Out:
# <Axes: xlabel='Age', ylabel='Flight Distance'>

# %% [markdown]
# This scatterplot shows that most passengers, who are between the ages of 25 and 60, travel long distances in business class.Someone flew a shorter distance and who traveled in an eco and eco plus class.

# %%
sns.set_style('whitegrid')
sns.scatterplot(y=arrival, x=departure,color='black')
# Out:
# <Axes: xlabel='Departure Delay in Minutes', ylabel='Arrival Delay in Minutes'>

# %% [markdown]
# This scatterplot shows that correlation  between the departure delay and arrival delay in min.The flights departure delay depends on flight arrived time.

# %%
sns.violinplot(x=departure)
# Out:
# <Axes: xlabel='Departure Delay in Minutes'>

# %%
departure.max()
# Out:
# 1128

# %%
sns.violinplot(x=arrival)
# Out:
# <Axes: xlabel='Arrival Delay in Minutes'>

# %%
arrival.max()
# Out:
# 1115.0

# %%
arrival=flight['Arrival Delay in Minutes']
departure=flight['Departure Delay in Minutes']
dep_arr_time=flight['Departure/Arrival time convenient']
online_booking=flight['Ease of Online booking']
customer_type=flight['Customer Type']
wifi=flight['Inflight wifi service']
food=flight['Food and drink']
seat_comfort=flight['Seat comfort']
checkin=flight['Checkin service']
cleaniness=flight['Cleanliness']

# %% [markdown]
# # Food and drinks ,Inflight wifi  and Seat comfort services
#
# The services provided on flights.Services are rated by passengers(0-5).

# %%
food_rating=food.value_counts()

# %%
plt.figure(figsize=(8,4))
px.bar(x=food_rating.index, y =food_rating,color=food_rating.index)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# This barplot shows that ratings of food and drinks services.most of the passengers gives rating 4 and 0 indicates no ratings given by the passengers.this plot shows the counts of passengers rating.

# %%
wifi_rating=wifi.value_counts()

# %%
px.bar(x=wifi_rating.index, y =wifi_rating)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# It shows that fewer passengers rated 5, with the majority rating 2 or 3. (here 0 mean no ratings).

# %%
seat_comfort=flight['Seat comfort']

# %%
seatcomfort_rating=seat_comfort.value_counts()

# %%
seatcomfort_rating
# Out:
# Seat comfort
# 4    7991
# 5    6688
# 3    4632
# 2    3632
# 1    3033
# Name: count, dtype: int64

# %%
plt.title('seat comfort services rating')
plt.pie(seatcomfort_rating,labels=seatcomfort_rating.index,autopct='%1.2f%%',startangle=190);

# %% [markdown]
# It shows that rating of 4 has highest frequency(30.76%),ratings 3 and 5 also have significant frequencies,indicating a generally positive perception of seat comfort among passengers.The lower ratings  1 and 2 have the least frequency.

# %% [markdown]
# # Satisfaction
#
# Let's examine airline passengers' level of satisfaction.To see its distribution, countplot might be utilized.

# %%
Satisfaction=flight['satisfaction']
satisfy=Satisfaction.value_counts()
satisfy
# Out:
# satisfaction
# neutral or dissatisfied    14573
# satisfied                  11403
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Gender', hue = 'satisfaction', palette = "PuRd",data=flight)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = Satisfaction, color='lightblue',edgecolor = "black",data=flight)
# Out:
# <Axes: xlabel='satisfaction', ylabel='count'>

# %% [markdown]
# It shows count of passengers expressing neutral or dissatisfied was higher than those who were satisfied passengers.This suggests that there may be several areas of the airline's service that could be improved to enhance passenger satisfaction.

# %% [markdown]
# ## Asking and Answering Questions
#
# We've already gained several insights about the respondents and the programming community by exploring individual columns of the dataset. Let's ask some specific questions and try to answer them using data frame operations and visualizations.

# %% [markdown]
# #### Q1: In which class passengers are more satisfied in airline services?
#
# To determine the passenger's level of satisfaction, we can utilize the 'Class' and 'satisfaction' columns in the flight data.

# %%
flight.Class.value_counts()
# Out:
# Class
# Business    12495
# Eco         11564
# Eco Plus     1917
# Name: count, dtype: int64

# %%
flight.satisfaction.value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    14573
# satisfied                  11403
# Name: count, dtype: int64

# %%
flight.groupby(['Class', 'satisfaction']).size().reset_index(name='count')
# Out:
#       Class             satisfaction  count
# 0  Business  neutral or dissatisfied   3809
# 1  Business                satisfied   8686
# 2       Eco  neutral or dissatisfied   9322
# 3       Eco                satisfied   2242
# 4  Eco Plus  neutral or dissatisfied   1442
# 5  Eco Plus                satisfied    475

# %%
sns.countplot(x = 'Class', hue = 'satisfaction', palette = "YlOrBr",data=flight)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# the number of passengers in business class are more satisfied compare to other class,while eco class passengers are noticeably more likely to be either neutral or unsatisfied.

# %% [markdown]
# ####Q2.what kinds of travel are more common on airlines?
# The flight data's "type of travel" column can be used to determine which kind of passengers fly with the airline most frequently.here value_counts() gives the count of the traveling type of passengers

# %%
travel=flight['Type of Travel']
travel.unique()
# Out:
# array(['Business travel', 'Personal Travel'], dtype=object)

# %%
travel.value_counts()
# Out:
# Type of Travel
# Business travel    18038
# Personal Travel     7938
# Name: count, dtype: int64

# %%
travel_type=travel.value_counts()

# %%
Llplt.title('type of travel')
plt.pie(travel_type,labels=travel_type.index,autopct='%.2f',startangle=190);

# %% [markdown]
#  It shows that significantly higher number of passenger are travelling for business purposes(18038) compared to those traveling for personal reasons(7938).the counts also suggests that the airline might be a popular choice among corporate or business travelers.

# %% [markdown]
# ####Q3.Which kind of traveler utilizes airlines the most and is the most satisfied?
#
# For this, we can use the 'Customer Type' and 'satisfaction' columns.to find out the satisfaction level of the passengers.

# %%
customer_type=flight['Customer Type']
customer_type.value_counts()
# Out:
# Customer Type
# Loyal Customer       21177
# disloyal Customer     4799
# Name: count, dtype: int64

# %%
Satisfaction=flight['satisfaction']
Satisfaction.value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    14573
# satisfied                  11403
# Name: count, dtype: int64

# %%
flight.groupby(['Customer Type','satisfaction']).size().reset_index(name='count')
# Out:
#        Customer Type             satisfaction  count
# 0     Loyal Customer  neutral or dissatisfied  10982
# 1     Loyal Customer                satisfied  10195
# 2  disloyal Customer  neutral or dissatisfied   3591
# 3  disloyal Customer                satisfied   1208

# %%
sns.countplot(x = 'Customer Type', hue = 'satisfaction', palette = "PuRd",data=flight)
# Out:
# <Axes: xlabel='Customer Type', ylabel='count'>

# %% [markdown]
# the number of loyal customers exceeds the number of disloyal customers.the presence of a significant number of loyal customers could be indicative of a positive overall customer experience and satisfaction with the airline's services.

# %% [markdown]
# ####Q4.How happy are travelers with the checkin services on their flights?(Related to ratings)
#
# Here we can use the 'check in services' column in flight data.

# %%
checkin=flight['Checkin service']

# %%
checkin_rating=checkin.value_counts()
checkin_rating
# Out:
# Checkin service
# 4    7278
# 3    7007
# 5    5264
# 1    3218
# 2    3209
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,4))
px.bar(x=checkin_rating.index, y =checkin_rating)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# It shows that ratings of 3 and 4 are more,suggesting that most passengers find the check in services to be stisfactory to good.The frequencies for level 1 and 2 are the lowest,indicating that there are relatively few passengers who are dissatisfied with the check in services

# %% [markdown]
# ## Inferences and Conclusions
# •	The age distribution showed a normal distribution with a skew towards younger age groups. Peaking in the age 30-40 age range.
#
# •	The gender distribution was balanced, The number of men and women in this sample is approximately the same.
#
# •	The majority of the airline's customers are loyal customers (repeat customers).
#
# •	There was a strong correlation (96%) between the features 'Departure delay in minutes' and 'Arrival delay in minutes'.
#
# •	Customers whose flight distance is long tend to fly in business class.
#
# •	The more distance an airplane passenger travels (respectively, the longer they are in flight), the more satisfied they are with in-flight entertainment.
#
# •	Most of the passengers who travel in Economy Plus or Economy Class were dissatisfied with the flight, and those who were travel in Business Class were satisfied.
#
# •	Almost all passengers who rated the wifi service 5 out of 5 were satisfied with the flight.
#
# •	The count of passengers expressing neutral or dissatisfaction was higher than those who were satisfied. Pointing towards potential areas for services improvement.

# %% [markdown]
# ## References and Future Work
#
# Check out the following resources to learn more about the dataset and tools used in this notebook:
#
# - Airline passenger satisfaction survey: https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction?select=test.csv
# - Pandas user guide: https://pandas.pydata.org/docs/user_guide/index.html
# - Matplotlib user guide: https://matplotlib.org/3.3.1/users/index.html
# - Seaborn user guide & tutorial: https://seaborn.pydata.org/tutorial.html
